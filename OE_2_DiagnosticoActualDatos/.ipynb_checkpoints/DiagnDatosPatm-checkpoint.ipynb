# %% [markdown]
# # Rutina de análisis inicial y de resultados de datos etiquetados durante QC a EMA

# %% [markdown]
# > Elaborado por Paola Álvarez, profesional contratista IDEAM, contrato 196 de 2024. Comentarios o inquietudes, remitir a *palvarez@ideam.gov.co*

# %% [markdown]
# El análisis de resultados se incluye dentro del documento de diagnóstico de series temporales.
# ___
# **Librerías:**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as mcolors
import matplotlib.image as mpimg
import glob
import os
import statistics
from matplotlib.ticker import FuncFormatter
from scipy import stats

# %% [markdown]
# _____

# %% [markdown]
# ### Longitud y continuidad series de datos de EMA - Gráficas

# %%
# Path to the directory containing the CSV files
data_directory = r"C:\Users\user\Downloads\PruebasDHIME"

# List to hold dataframes
dataframes = []

# Load each CSV file into a dataframe and add it to the list
for filename in os.listdir(data_directory):
    if filename.endswith(".csv"):
        try:
            df = pd.read_csv(os.path.join(data_directory, filename), parse_dates=['Fecha'], encoding='latin-1')
            df.set_index('Fecha', inplace=True)
            df['Presence'] = 1  # Add a column to indicate data presence
            dataframes.append(df)
        except Exception as e:
            print(f"Error loading {filename}: {e}")

# Se muestran los headers y fechas por archivo para ver estructura - Para caso de ejemplo
#dataframes_info = [(df.head(), df.index.min(), df.index.max()) for df in dataframes]
#dataframes_info

# %%
# Esta si
# Ordenar lista de dataframes
dataframes = sorted(dataframes, key=lambda x: x['Station'].iloc[0])

# Se crea el date range con las fechas inicial y final conocidas, para presión atmosférica 01/01/2001 a 03/04/2024, horaria
date_range = pd.date_range(start="2001-01-01 00:00", end="2024-04-03 23:00", freq='H')

# Número de estaciones por gráfico
estaciones_por_grafico = 50

# Total de gráficos a generar
total_graficos = len(dataframes) // estaciones_por_grafico + (len(dataframes) % estaciones_por_grafico > 0)

# Configuración de la fuente para todo el gráfico
font = {'family': 'Franklin Gothic Book',
        'weight': 'normal',
        'size': 10}

plt.rc('font', **font)

for j in range(total_graficos):
    fig, ax = plt.subplots(figsize=(15, 10))
    inicio = j * estaciones_por_grafico
    fin = min(inicio + estaciones_por_grafico, len(dataframes))  # Asegurarse de no pasarse del rango

    # Define a helper function to plot data for clarity
    def plot_station_data(ax, data, index, station_label):
        # Find where data is present
        presence_mask = data['Presence'] == 1
        # Plot only where data is present
        ax.fill_between(data.index, index - 0.45, index + 0.45, where=~presence_mask, color='#f0f0f0', step='mid', label='Sin dato' if i == 1 else "")
        ax.fill_between(data.index, index - 0.45, index + 0.45, where=presence_mask, color='orange', step='mid', label='Con dato' if i == 1 else "")

    for i, df in enumerate(dataframes[inicio:fin], start=1):
        # Reindex the dataframe to the full date range, filling missing data with 0 (indicating absence)
        df_complete = df.reindex(date_range, fill_value=0)
        plot_station_data(ax, df_complete, i, f"Station {df['Station'].iloc[0]}")

    #ax.legend(loc='upper left')  # Agrega la leyenda en la esquina superior izquierda
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=True, ncol=2)
    # Setting the labels and ticks for better readability
    ax.set_yticks(range(1, fin - inicio + 1))
    ax.set_yticklabels([f"{df['Station'].iloc[0]}" for df in dataframes[inicio:fin]], fontsize=8)
    ax.set_ylim(0.5, fin - inicio + 0.5)
    ax.set_xlim(date_range[0], date_range[-1])
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.xaxis.set_minor_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    plt.xticks(rotation=90)
    plt.ylabel('Código de estación CNE')
    plt.title(f'Completitud de datos por estación - Grupo de estaciones {j+1} de {total_graficos}')
    plt.grid(True, which='both', linestyle='-', linewidth=0.25)

    # Show and save the plot
    plt.tight_layout()
    plt.savefig(f'completitud_datos_grafico_{j+1}.png')  # Guarda el gráfico como un archivo PNG
    plt.close(fig)  # Cierra la figura para liberar memoria

# %%
from matplotlib import font_manager
fonts = [f.name for f in font_manager.fontManager.ttflist]
print(set(fonts))
# Out:
# {'Franklin Gothic Demi', 'Cambria', 'Lucida Sans Unicode', 'Stencil', 'Niagara Engraved', 'Harlow Solid Italic', 'Calibri', 'ESRI AMFM Water', 'Haettenschweiler', 'Microsoft PhagsPa', 'ESRI Meteorological 01', 'Curlz MT', 'Oswald', 'Century', 'DejaVu Sans Display', 'cmex10', 'Microsoft Tai Le', 'Chiller', 'Gigi', 'Maiandra GD', 'ESRI Pipeline US 1', 'Bradley Hand ITC', 'Edwardian Script ITC', 'SimSun-ExtB', 'HoloLens MDL2 Assets', 'ESRI IGL Font16', 'High Tower Text', 'ESRI SDS 1.95 1', 'Pristina', 'Myanmar Text', 'MingLiU-ExtB', 'ESRI Telecom', 'Lucida Handwriting', 'Harrington', 'Rockwell Extra Bold', 'Palace Script MT', 'Vivaldi', 'ESRI MilSym 03', 'Trebuchet MS', 'ESRI AMFM Electric', 'MT Extra', 'ESRI Weather', 'Playbill', 'ESRI IGL Font23', 'ESRI US MUTCD 3', 'Imprint MT Shadow', 'Segoe UI Emoji', 'DejaVu Serif Display', 'Perpetua', 'ESRI Commodities', 'Rockwell', 'ESRI Surveyor', 'Franklin Gothic Heavy', 'Dosis', 'Franklin Gothic Demi Cond', 'STIXSizeFiveSym', 'Tw Cen MT Condensed Extra Bold', 'Gill Sans Ultra Bold Condensed', 'ESRI MilSym 01', 'Lucida Console', 'Leelawadee', 'Symbol', 'Bernard MT Condensed', 'ESRI Elements', 'ESRI MilRed 01', 'Palatino Linotype', 'DejaVu Serif', 'ESRI NIMA DNC PT', 'ESRI Conservation', 'ESRI AMFM Gas', 'ESRI Hydrants', 'Monotype Corsiva', 'Jokerman', 'ESRI Geology AGSO 1', 'Old English Text MT', 'Castellar', 'Webdings', 'Marlett', 'ESRI NIMA City Graphic PT', 'Vladimir Script', 'ESRI Enviro Hazard Analysis', 'ESRI IGL Font24', 'ESRI Geology', 'cmr10', 'MV Boli', 'Franklin Gothic Medium Cond', 'Garamond', 'STIXSizeThreeSym', 'French Script MT', 'Parchment', 'Times New Roman', 'ESRI ERS Infrastructures S1', 'OCR A Extended', 'ESRI NIMA VMAP1&2 LN', 'Felix Titling', 'Rockwell Condensed', 'STIXNonUnicode', 'Gill Sans Ultra Bold', 'ESRI Geometric Symbols', 'ESRI ArcPad', 'ESRI Hazardous Materials', 'Copperplate Gothic Bold', 'Script MT Bold', 'Ravie', 'Bauhaus 93', 'MS Reference Specialty', 'Freestyle Script', 'Century Schoolbook', 'Gloucester MT Extra Condensed', 'Goudy Stout', 'Comic Sans MS', 'Lato', 'STIXSizeOneSym', 'Niagara Solid', 'ESRI Default Marker', 'Centaur', 'Montserrat', 'Gill Sans MT Condensed', 'ESRI NIMA City Graphic LN', 'Microsoft New Tai Lue', 'Tahoma', 'Agency FB', 'Bodoni MT', 'Wingdings 2', 'ESRI Crime Analysis', 'Segoe Script', 'Franklin Gothic Medium', 'Gadugi', 'Segoe UI Historic', 'Gill Sans MT Ext Condensed Bold', 'Juice ITC', 'ESRI Ordnance Survey', 'Candara', 'ESRI Caves 1', 'ESRI IGL Font21', 'Impact', 'Corbel', 'Copperplate Gothic Light', 'Rage Italic', 'Segoe UI Symbol', 'Wingdings', 'ESRI US MUTCD 2', 'STIXGeneral', 'Franklin Gothic Book', 'Georgia', 'Courier New', 'STIXSizeFourSym', 'Wide Latin', 'Yu Gothic', 'Berlin Sans FB Demi', 'ESRI NIMA DNC LN', 'Lucida Sans', 'Arial', 'cmb10', 'Javanese Text', 'Eras Light ITC', 'Brush Script MT', 'Dubai', 'Onyx', 'ESRI SDS 2.00 2', 'ESRI MilSym 04', 'ESRI MilMod 01', 'Papyrus', 'Segoe MDL2 Assets', 'Californian FB', 'Berlin Sans FB', 'Ebrima', 'Algerian', 'Magneto', 'ESRI Caves 3', 'Britannic Bold', 'Cooper Black', 'Poor Richard', 'Source Sans Pro', 'Tw Cen MT Condensed', 'TeamViewer15', 'ESRI Dimensioning', 'Snap ITC', 'STIXSizeTwoSym', 'ESRI Transportation & Civic', 'Showcard Gothic', 'Engravers MT', 'Kunstler Script', 'Microsoft Sans Serif', 'ESRI SDS 2.00 1', 'Segoe Print', 'Forte', 'ESRI NIMA VMAP1&2 PT', 'Baskerville Old Face', 'Microsoft Himalaya', 'DejaVu Sans', 'ESRI ERS Operations S1', 'Constantia', 'Elephant', 'Microsoft Uighur', 'Microsoft JhengHei', 'MS Gothic', 'Eras Medium ITC', 'ESRI Business', 'Consolas', 'Kristen ITC', 'Century Gothic', 'Segoe UI', 'Bahnschrift', 'ESRI AMFM Sewer', 'Broadway', 'Calisto MT', 'cmsy10', 'Mongolian Baiti', 'Gabriola', 'Wingdings 3', 'ESRI MilSym 02', 'Microsoft Yi Baiti', 'ESRI Climate & Precipitation', 'ESRI Environmental & Icons', 'ESRI US Forestry 1', 'Microsoft YaHei', 'Goudy Old Style', 'ESRI Public1', 'cmss10', 'ESRI SDS 1.95 2', 'ESRI Shields', 'Sitka Small', 'L ...

# %% [markdown]
# ### Cantidad total de datos

# %%
## Se indaga sobre cuál es la cantidad de datos de todas las series descargadas en el período 2001-01-01 al 2024-03-31
# Se crea la función cantidad_datos
def cantidad_datos(archivos):
    total_filas = 0

    for archivo in archivos:
        # Se utiliza el método 'chunksize' de pandas para leer los archivos por partes (chunks)
        # y procesarlos de forma incremental sin cargar todos los datos en memoria al mismo tiempo
        chunks = pd.read_csv(archivo, encoding='latin-1', chunksize=100000)  # Se establece este valor de chunk para poder hacer otras actividades

        for chunk in chunks:
            total_filas += len(chunk)

    return total_filas

# Ruta de la carpeta con los archivos CSV
carpeta_proces = 'RawUnmodified_Patm/'

# Obtener la lista de archivos en la carpeta
archivos = [carpeta_proces + archivo for archivo in os.listdir(carpeta_proces) if archivo.endswith('.csv')]

# Llamar a la función para contar las filas
total_filas = cantidad_datos(archivos)

# Imprimir el resultado
print("El número total de datos es:", total_filas)
# Out:
# El número total de datos es: 22112997

# %% [markdown]
# ### Contar datos por fecha

# %%
def contar_datos_por_fechas(archivos):
    resultados = []

    for archivo in archivos:
        chunks = pd.read_csv(archivo, encoding='latin-1', chunksize=100000)
        
        for chunk in chunks:
            chunk['Fecha'] = pd.to_datetime(chunk['Fecha'], format='%Y-%m-%d %H:%M:%S.%f')
            estacion = chunk['Station'].iloc[0]
            
            # Conteo por año, mes y día
            conteo_dia = chunk['Fecha'].dt.to_period('D').value_counts().rename_axis('Año-mes-dia').reset_index(name='Cantidad_año-mes-dia')
            conteo_dia['Año-mes'] = conteo_dia['Año-mes-dia'].dt.to_timestamp().dt.to_period('M')
            conteo_dia['Año'] = conteo_dia['Año-mes'].dt.year

            # Conteo por año y mes
            conteo_mes = chunk['Fecha'].dt.to_period('M').value_counts().rename_axis('Año-mes').reset_index(name='Cantidad_año-mes')
            conteo_mes['Año'] = conteo_mes['Año-mes'].dt.year

            # Conteo por año
            conteo_anual = chunk['Fecha'].dt.year.value_counts().rename_axis('Año').reset_index(name='Cantidad_año')
            
            # Combinar con la información de la estación
            conteo_anual['Station'] = estacion
            conteo_mes['Station'] = estacion
            conteo_dia['Station'] = estacion
            
            # Merge considerando Station, Año y Año-mes
            merged_data = pd.merge(pd.merge(conteo_anual, conteo_mes, on=['Station', 'Año']), conteo_dia, on=['Station', 'Año', 'Año-mes'])
            resultados.append(merged_data)
    
    df_resultados = pd.concat(resultados, ignore_index=True)
    # Reordenar columnas
    df_resultados = df_resultados[['Station', 'Año', 'Cantidad_año', 'Año-mes', 'Cantidad_año-mes','Año-mes-dia','Cantidad_año-mes-dia']]
    df_resultados.sort_values(by=['Station', 'Año', 'Año-mes', 'Año-mes-dia'], inplace=True)
    
    # Rellenar la columna 'Cantidad_año' sólo una vez por cada año y estación
    df_resultados['Cantidad_año'] = df_resultados.groupby(['Station', 'Año'])['Cantidad_año'].transform(lambda x: x.iloc[0] if not x.isna().all() else pd.NA)
    
    df_resultados.to_csv('conteo_datos_detalles_completo.csv', index=False, encoding='latin-1')
    return df_resultados

# Uso de la función
carpeta_proces = 'RawUnmodified_Patm/'
archivos = [carpeta_proces + archivo for archivo in os.listdir(carpeta_proces) if archivo.endswith('.csv')]
resultados = contar_datos_por_fechas(archivos)
print(resultados.head())
# Out:
#        Station   Año  Cantidad_año  Año-mes  Cantidad_año-mes Año-mes-dia  \
# 1240  11030010  2018          5726  2018-05               659  2018-05-04
# 1213  11030010  2018          5726  2018-05               659  2018-05-05
# 1233  11030010  2018          5726  2018-05               659  2018-05-06
# 1232  11030010  2018          5726  2018-05               659  2018-05-07
# 1231  11030010  2018          5726  2018-05               659  2018-05-08
#
#       Cantidad_año-mes-dia
# 1240                    11
# 1213                    24
# 1233                    24
# 1232                    24
# 1231                    24

# %%
### Lectura de frecuencias para revisión inicial
dffreq = pd.read_csv('conteo_datos_detalles_completo.csv', encoding='latin-1')
dffreq
# Out:
#            Station   Año  Cantidad_año  Año-mes  Cantidad_año-mes Año-mes-dia  \
# 0         11030010  2018          5726  2018-05               659  2018-05-04
# 1         11030010  2018          5726  2018-05               659  2018-05-05
# 2         11030010  2018          5726  2018-05               659  2018-05-06
# 3         11030010  2018          5726  2018-05               659  2018-05-07
# 4         11030010  2018          5726  2018-05               659  2018-05-08
# ...            ...   ...           ...      ...               ...         ...
# 796775  5311500149  2024          8244  2024-03               622  2024-03-01
# 796776  5311500149  2024          8244  2024-03               622  2024-03-02
# 796777  5311500149  2024          8244  2024-03               622  2024-03-03
# 796778  5311500149  2024          8244  2024-03               622  2024-03-04
# 796779  5311500149  2024          8244  2024-03               622  2024-03-05
#
#         Cantidad_año-mes-dia
# 0                         11
# 1                         24
# 2                         24
# 3                         24
# 4                         24
# ...                      ...
# 796775                   138
# 796776                   144
# 796777                   144
# 796778                   144
# 796779                    52
#
# [796780 rows x 7 columns]

# %%
grupito = dffreq.groupby(dffreq['Station'])

# %%
grp_mx = grupito['Cantidad_año-mes-dia'].max()
grp_mx.to_csv('grp_mx.csv', encoding='latin-1', index=True, sep=';')

# %% [markdown]
# ### Obtener fechas iniciales y finales de estaciones

# %%
def obtener_fechas(archivo):
    try:
        # Se lee el archivo
        datos = pd.read_csv(archivo, encoding='latin-1')#, names=['Fecha', 'Valor'])
        try:
            datos['Fecha'] = pd.to_datetime(datos['Fecha'], format='%Y-%m-%d %H:%M:%S.%f')
        except ValueError:
            datos['Fecha'] = pd.to_datetime(datos['Fecha'], format='%Y-%m-%d %H:%M:%S')
        
        # Se obtiene el código de la estación
        station = #datos['Station'].values[0]
        
        # Se obtiene primera y última fecha 
        fecha_inicial = datos['Fecha'].iloc[0]
        fecha_final = datos['Fecha'].iloc[-1]
        
        return station, fecha_inicial, fecha_final
    
    except Exception as e:
        print(f"Error con el archivo {archivo}: {e}")
        return None, None, None

def main():
    # Cambia la ruta según la ubicación de tu carpeta
    ruta_carpeta = r'C:\Users\user\Downloads\PruebasDHIME'

    # Listamos todos los archivos en la carpeta que terminen con .csv
    archivos = [f for f in os.listdir(ruta_carpeta) if f.endswith('.csv')]
    
    # Creamos una lista para almacenar los resultados
    resultados = []

    # Iteramos sobre cada archivo y obtenemos las fechas
    for archivo in archivos:
        ruta_archivo = os.path.join(ruta_carpeta, archivo)
        station, fecha_inicial, fecha_final = obtener_fechas(ruta_archivo)
        
        if station and fecha_inicial and fecha_final:
            resultados.append([station, fecha_inicial, fecha_final])
    
    # Convertimos los resultados a un DataFrame
    resultados_df = pd.DataFrame(resultados, columns=['CodEstacion', 'fecha_inicial', 'fecha_final'])
    
    # Guardamos el DataFrame como un archivo CSV
    resultados_df.to_csv('FechaInicialFinal_DHIME.csv', index=False)

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Obtener estadísticos descriptivos

# %%
def obtener_EstadDescript(archivo):
    try:
        # Se lee el archivo
        datos = pd.read_csv(archivo, encoding='latin-1')#, names=['Fecha', 'Valor'])
        try:
            datos['Fecha'] = pd.to_datetime(datos['Fecha'], format='%Y-%m-%d %H:%M:%S.%f')
        except ValueError:
            datos['Fecha'] = pd.to_datetime(datos['Fecha'], format='%Y-%m-%d %H:%M:%S')
        
        # Se obtiene el código de la estación
        station = datos['Station'].values[0]
        
        # Se obtienen los estadísticos descriptivos
        minimo = datos['Valor'].min()
        maximo = datos['Valor'].max()
        media = datos['Valor'].mean()
        mediana = datos['Valor'].median()
        desvest = datos['Valor'].std()
        varianza = datos['Valor'].var()
        #first_q = datos['Valor'].quantile(0.25)
        #third_q = datos['Valor'].quantile(0.75)
        
        return station, minimo, maximo, media, mediana, desvest, varianza, #first_q, third_q, mediana --no fue posible calcular estos estad.
    
    except Exception as e:
        print(f"Error con el archivo {archivo}: {e}")
        print(e.__class__)
        return None, None, None, None, None, None, None#, None, None --no fue posible calcular estos estad.

def main():
    # Cambia la ruta según la ubicación de tu carpeta
    ruta_carpeta = 'RawUnmodified_Patm'

    # Listamos todos los archivos en la carpeta que terminen con .csv
    archivos = [f for f in os.listdir(ruta_carpeta) if f.endswith('.csv')]
    
    # Se crea una lista para almacenar los resultados
    resultados = []

    # Se itera sobre cada archivo y se obtienen fechas las fechas
    for archivo in archivos:
        ruta_archivo = os.path.join(ruta_carpeta, archivo)
        station, minimo, maximo, media, mediana, desvest, varianza= obtener_EstadDescript(ruta_archivo)
        print(station, minimo, maximo, media, mediana, desvest, varianza)
        resultados.append([station, minimo, maximo, media, mediana, desvest, varianza])
        #if station and minimo: #and maximo and media and mediana and desvest and varianza:
            #resultados.append([station, minimo, maximo, media, mediana, desvest, varianza])
        #else:
            #print(f'Sin suficientes resultado para {archivo}. No se generaron sus estadísticos')
    
    # Se convierten los resultados a un DataFrame
    resultados_df = pd.DataFrame(resultados, columns=['Station', 'minimo', 'maximo', 'media', 'mediana','desvest', 'varianza'])
    
    print(resultados_df)
    
    # Se guarda el DataFrame como un archivo CSV
    resultados_df.to_csv('EstadDescript_Patm_Raw.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# 11030010 977.9 1037.9 1006.1994866774903 1006.3 2.4399384018078085 5.953299404616442
# 11035030 155.0 41115.0 1007.2317907025225 999.6 516.1658334782674 266427.16765031446
# 11045010 996.9 1010.8 1004.702345555908 1004.8 2.042558786488141 4.172046396259907
# 11050020 1000.6 1014.5 1007.7899064617735 1007.9 2.0775243080055734 4.316107250354037
# 11080010 1002.0 1015.9 1009.5999130863054 1009.7 2.1032925073048063 4.423839371284538
# 11105020 -2055.2 3277.8 811.2659169814616 1008.6 400.36488324744056 160292.0397377367
# 11115020 865.9 878.2 872.9511947294241 873.0 1.6119911404855216 2.5985154370038126
resultados_df = pd.read_csv('EstadDescript_Patm_Raw.csv')

# %%
altipatm = pd.read_table('EMA_Patm_TMaxMin.txt', sep=';')

# %%
altipatm.head(2)
# Out:
#    OBJECTID     Station    lat   long_ nombre       sede  id_rule  codigo  \
# 0         1  11030010.0  5.375 -76.613  Valle  09 - Cali        9       9
# 1         2  11035030.0  5.285 -76.628  Valle  09 - Cali        9       9
#
#   Instituc FreqInf  Altitud   TmaxNorm   TminNorm
# 0    IDEAM       H       58  27.853392  19.794912
# 1    IDEAM       H      104  27.376471  19.418962

# %%
estadalt = pd.merge(resultados_df, altipatm[['Station','Altitud']], on='Station')

# %%
# Se sobreescriben los estadísticos para incluir altitud
estadalt.to_csv('EstadDescript_Patm_Raw.csv', index=False)

# %%
# De datos con QC
def obtener_EstadDescript(archivo):
    try:
        # Se lee el archivo
        datos = pd.read_csv(archivo, encoding='latin-1')#, names=['Fecha', 'Valor'])
        try:
            datos['Fecha'] = pd.to_datetime(datos['Fecha'], format='%Y-%m-%d %H:%M:%S.%f')
        except ValueError:
            datos['Fecha'] = pd.to_datetime(datos['Fecha'], format='%Y-%m-%d %H:%M:%S')
        
        # Se hace el filtro para que solo queden los valores que superaron las pruebas
        dfC = datos[~datos['Estado'].apply(lambda x: any([str(x).startswith(prefix) for prefix in ['0PSO','0PAT','0PER']]))]
        
        # Se obtiene el código de la estación
        station = dfC['Station'].values[0]
        
        # Se obtienen los estadísticos descriptivos
        minimo = dfC['Valor'].min()
        maximo = dfC['Valor'].max()
        media = dfC['Valor'].mean()
        #mediana = datos['Valor'].median()
        desvest = dfC['Valor'].std()
        varianza = dfC['Valor'].var()
        #first_q = datos['Valor'].quantile(0.25)
        #third_q = datos['Valor'].quantile(0.75)
        
        return station, minimo, maximo, media, desvest, varianza, #first_q, third_q, mediana --no fue posible calcular estos estad.
    
    except Exception as e:
        print(f"Error con el archivo {archivo}: {e}")
        print(e.__class__)
        return None, None, None, None, None, None#, None, None, None --no fue posible calcular estos estad.

def main():
    # Cambia la ruta según la ubicación de tu carpeta
    #ruta_carpeta = '../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V2'
    ruta_carpeta = '../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3'

    # Listamos todos los archivos en la carpeta que terminen con .csv
    archivos = [f for f in os.listdir(ruta_carpeta) if f.endswith('.csv')]
    
    # Creamos una lista para almacenar los resultados
    resultados = []

    # Iteramos sobre cada archivo y obtenemos las fechas
    for archivo in archivos:
        ruta_archivo = os.path.join(ruta_carpeta, archivo)
        station, minimo, maximo, media, desvest, varianza= obtener_EstadDescript(ruta_archivo)
        
        if station and minimo and maximo and media and desvest and varianza:
            resultados.append([station, minimo, maximo, media, desvest, varianza])
    
    # Convertimos los resultados a un DataFrame
    resultados_df = pd.DataFrame(resultados, columns=['Station', 'minimo', 'maximo', 'media', 'desvest', 'varianza'])
    
    # Guardamos el DataFrame como un archivo CSV
    resultados_df.to_csv('EstadDescript_QC_V3.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021085030_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021185090_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021197430_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021205506_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021205509_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021205513_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021205514_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021205515_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021205516_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021206940_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021237020_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021237060_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0021255160_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0022065040_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0023065160_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0023067020_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0023195040_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0024027070_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0024030350_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0024035360_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0024035390_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# C:\Users\user\AppData\Local\Temp\ipykernel_9308\7780786.py:5: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos = pd.read_csv(archivo, encoding='latin-1')#, names=['Fecha', 'Valor'])
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0025025002_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0026155270_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0026185020_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0026200120_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0027015300_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0028015110_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0029045150_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0029065140_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0032067030_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0035017020_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0035027510_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0035037100_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0035105050_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0035195020_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0035237040_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0051025080_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0054017040_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_0054025010_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_1501500054_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_1602500063_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_2120500204_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_2120700162_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_2202500051_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_2401500052_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_2603500127_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_2612500124_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_3507500133_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>
# Error con el archivo ../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3\Estacion_3701500117_qc.csv: index 0 is out of bounds for axis 0 with size 0
# <class 'IndexError'>

# %%
## Analizar presencia de '0PSO0'
# Se lee la carpeta del ejemplo
# Directorio de ejemplo
directorio = r'../OE_3_QC_Variables/2_HumedadRelativa/RawUnmodified_HR/p_transm'

# Lista para almacenar los nombres de los archivos y conteos de '0PSO0'
archivos_con_0PSO0 = []

# Iterar sobre cada archivo en el directorio
for archivo in os.listdir(directorio):
    if archivo.endswith('.csv'):
        # Construir la ruta completa al archivo
        ruta_archivo = os.path.join(directorio, archivo)
        
        # Leer el archivo CSV en un DataFrame de pandas
        tipos_de_dato = {'Estado': str, 'Estado_Anterior': str}
        df = pd.read_csv(ruta_archivo, dtype=tipos_de_dato, encoding='latin-1')
        
        # Contar las ocurrencias de '0PLP0' en la columna 'Estado'
        if 'Estado' not in df.columns:
            continue
        
        # Si el conteo es mayor que cero, agregar el archivo y el conteo a la lista
        if conteo_0PSO0 > 0:
            archivos_con_0PSO0.append((archivo, conteo_0PSO0))
            #print(archivos_con_0PSO0)
            #qtty_ptransm = pd.DataFrame(archivos_con_0PSO0)
            #print(qtty_ptransm)
#qtty_ptransm.to_csv('ptransm_qtty.csv')
# Imprimir los nombres de los archivos y los conteos de '0PSO0' en la columna 'Estado'
print('Archivos que contienen "0PSO0" en la columna "Estado" y su conteo:')
for archivo, conteo in archivos_con_0PSO0:
    print(f'{archivo}: {conteo} veces')
# Out:
# Archivos que contienen "0PSO0" en la columna "Estado" y su conteo:
# Estacion_0011025501_paresultado.csv: 1847 veces
# Estacion_0011030010_paresultado.csv: 1847 veces
# Estacion_0011035030_paresultado.csv: 1847 veces
# Estacion_0011045010_paresultado.csv: 1847 veces
# Estacion_0011050020_paresultado.csv: 1847 veces
# Estacion_0011080010_paresultado.csv: 1847 veces
# Estacion_0011105020_paresultado.csv: 1847 veces
# Estacion_0011115020_paresultado.csv: 1847 veces
# Estacion_0011115501_paresultado.csv: 1847 veces
# Estacion_0011120040_paresultado.csv: 1847 veces
# Estacion_0011135030_paresultado.csv: 1847 veces
# Estacion_0011159010_paresultado.csv: 1847 veces
# Estacion_0011175000_paresultado.csv: 1847 veces
# Estacion_0012015060_paresultado.csv: 1847 veces
# Estacion_0012015100_paresultado.csv: 1847 veces
# Estacion_0012015110_paresultado.csv: 1847 veces
# Estacion_0012025040_paresultado.csv: 1847 veces
# Estacion_0012045020_paresultado.csv: 1847 veces
# Estacion_0013035501_paresultado.csv: 1847 veces
# Estacion_0013055040_paresultado.csv: 1847 veces
# Estacion_0013085030_paresultado.csv: 1847 veces
# Estacion_0013095010_paresultado.csv: 1847 veces
# Estacion_0014015010_paresultado.csv: 1847 veces
# Estacion_0014015020_paresultado.csv: 1847 veces
# Estacion_0014015080_paresultado.csv: 1847 veces
# Estacion_0014017001_paresultado.csv: 1847 veces
# Estacion_0015015050_paresultado.csv: 1847 veces
# Estacion_0015015060_paresultado.csv: 1847 veces
# Estacion_0015015100_paresultado.csv: 1847 veces
# Estacion_0015015120_paresultado.csv: 1847 veces
# Estacion_0015065040_paresultado.csv: 1847 veces
# Estacion_0015065180_paresultado.csv: 1847 veces
# Estacion_0015065190_paresultado.csv: 1847 veces
# Estacion_0015075150_paresultado.csv: 1847 veces
# Estacion_0015075501_paresultado.csv: 1847 veces
# Estacion_0015085030_paresultado.csv: 1847 veces
# Estacion_0015085050_paresultado.csv: 1847 veces
# Estacion_0016015110_paresultado.csv: 1847 veces
# Estacion_0016015120_paresultado.csv: 1847 veces
# Estacion_0016015130_paresultado.csv: 1847 veces
# Estacion_0016015501_paresultado.csv: 1847 veces
# Estacion_0016015502_paresultado.csv: 1847 veces
# Estacion_0016025040_paresultado.csv: 1847 veces
# Estacion_0016025501_paresultado.csv: 1847 veces
# Estacion_0016025502_paresultado.csv: 1847 veces
# Estacion_0016025503_paresultado.csv: 1847 veces
# Estacion_0016035501_paresultado.csv: 1847 veces
# Estacion_0016040050_paresultado.csv: 1847 veces
# Estacion_0016055120_paresultado.csv: 1847 veces
# Estacion_0016055501_paresultado.csv: 1847 veces
# Estacion_0017015010_paresultado.csv: 1847 veces
# Estacion_0017017001_paresultado.csv: 1847 veces
# Estacion_0017025020_paresultado.csv: 1847 veces
# Estacion_0021015040_paresultado.csv: 1847 veces
# Estacion_0021015060_paresultado.csv: 1847 veces
# Estacion_0021015070_paresultado.csv: 1847 veces
# Estacion_0021015501_paresultado.csv: 1847 veces
# Estacion_0021015502_paresultado.csv: 1847 veces
# Estacion_0021035040_paresultado.csv: 1847 veces
# Estacion_0021035501_paresultado.csv: 1847 veces
# Estacion_0021045010_paresultado.csv: 1847 veces
# Estacion_0021045501_paresultado.csv: 1847 veces
# Estacion_0021050060_paresultado.csv: 1847 veces
# Estacion_0021050090_paresultado.csv: 1847 veces
# Estacion_0021055020_paresultado.csv: 1847 veces
# Estacion_0021055501_paresultado.csv: 1847 veces
# Estacion_0021065040_paresultado.csv: 1847 veces
# Estacion_0021065501_paresultado.csv: 1847 veces
# Estacion_0021085030_paresultado.csv: 1847 veces
# Estacion_0021085501_paresultado.csv: 1847 veces
# Estacion_0021105030_paresultado.csv: 1847 veces
# Estacion_0021105501_paresultado.csv: 1847 veces
# Estacion_0021115010_paresultado.csv: 1847 veces
# Estacion_0021115100_paresultado.csv: 1847 veces
# Estacion_0021115170_paresultado.csv: 1847 veces
# Estacion_0021115180_paresultado.csv: 1847 veces
# Estacion_0021115501_paresultado.csv: 1847 veces
# Estacion_0021125010_paresultado.csv: 1847 veces
# Estacion_0021130050_paresultado.csv: 1847 veces
# Estacion_0021135020_paresultado.csv: 1847 veces
# Estacion_0021140120_paresultado.csv: 1847 veces
# Estacion_0021145080_paresultado.csv: 1847 veces
# Estacion_0021165501_paresultado.csv: 1847 veces
# Estacion_0021165502_paresultado.csv: 1847 veces
# Estacion_0021185030_paresultado.csv: 1847 veces
# Estacion_0021185080_paresultado.csv: 1847 veces
# Estacion_0021185090_paresultado.csv: 1847 veces
# Estacion_0021185501_paresultado.csv: 1847 veces
# Estacion_0021195120_paresultado.csv: 1847 veces
# Estacion_0021195160_paresultado.csv: 1847 veces
# Estacion_0021195170_paresultado.csv: 1847 veces
# Estacion_0021195190_paresultado.csv: 1847 veces
# Estacion_0021195501_paresultado.csv: 1847 veces
# Estacion_0021195502_paresultado.csv: 1847 veces
# Estacion_0021197430_paresultado.csv: 1847 veces
# Estacion_0021201200_paresultado.csv: 1847 veces
# Estacion_0021201980_paresultado.csv: 1847 veces
# Estacion_0021202170_paresultado.csv: 1847 veces
# Estacion_0021202180_paresultado.csv: 1847 veces
# Estacion_0021202200_paresultado.csv: 1847 veces
# Estacion_0021202220_paresultado.csv: 1847 veces
# Estacion_0021202230_paresultado.csv: 1847 veces
# Estacion_0021202240_paresultado.csv: 1847 veces
# Estacion_0021202250_paresultado.csv: 1847 veces
# Estacion_0021205012_paresultado.csv: 1847 veces
# Estacion_0021205480_paresultado.csv: 1847 veces
# Estacion_0021205501_paresultado.csv: 1847 veces
# Estacion_0021205502_paresultado.csv: 1847 veces
# Estacion_0021205503_paresultado.csv: 1847 veces
# Estacion_0021205505_paresultado.csv: 1847 veces
# Estacion_0021205506_paresultado.csv: 1847 veces
# Estacion_0021205507_paresultado.csv: 1847 veces
# Estacion_0021205509_paresultado.csv: 1847 veces
# Estacion_0021205511_paresultado.csv: 1847 veces
# Estacion_0021205512_paresultado.csv: 1847 veces
# Estacion_0021205513_paresultado.csv: 1847 veces
# Estacion_0021205514_paresultado.csv: 1847 veces
# Estacion_0021205515_paresultado.csv: 1847 veces
# Estacion_0021205516_paresultado.csv: 1847 veces
# Estacion_0021205517_paresultado.csv: 1847 veces
# Estacion_0021205518_paresultado.csv: 1847 veces
# Estacion_0021205519_paresultado.csv: 1847 veces
# Estacion_0021205521_paresultado.csv: 1847 veces
# Estacion_0021205522_paresultado.csv: 1847 veces
# Estacion_0021205523_paresultado.csv: 1847 veces
# Estacion_0021205524_paresultado.csv: 1847 veces
# Estacion_0021205525_paresultado.csv: 1847 veces
# Estacion_0021205526_paresultado.csv: 1847 veces
# Estacion_0021205527_paresultado.csv: 1847 veces
# Estacion_0021205660_paresultado.csv: 1847 veces
# Estacion_0021205670_paresultado.csv: 1847 veces
# Estacion_0021205710_paresultado.csv: 1847 veces
# Estacion_0021205791_paresultado.csv: 1847 veces
# Estacion_0021205910_paresultado.csv: 1847 veces
# Estacion_0021205940_paresultado.csv: 1847 veces
# Estacion_0021205970_paresultado.csv: 1847 veces
# Estacion_0021206280_paresultado.csv: 1847 veces
# Estacion_0021206560_paresultado.csv: 1847 veces
# Estacion_0021206600_paresultado.csv: 1847 veces
# Estacion_0021206780_paresultado.csv: 1847 veces
# Estacion_0021206790_paresultado.csv: 1847 veces
# Estacion_0021206810_paresultado.csv: 1847 veces
# Estacion_0021206890_paresultado.csv: 1847 veces
# Estacion_0021206920_paresultado.csv: 1847 veces
# Estacion_0021206930_paresultado.csv: 1847 veces
# Estacion_0021206940_paresultado.csv: 1847 veces
# Estacion_0021206950_paresultado.csv: 1847 veces
# Estacion_0021206960_paresultado.csv: 1847 veces
# Estacion_0021206980_paresultado.csv: 1847 veces
# Estacion_0021206990_paresultado.csv: 1847 veces
# Estacion_0021208480_paresultado.csv: 1847 veces
# Estacion_0021209940_paresultado.csv: 1847 veces
# Estacion_0021215150_paresultado.csv: 1847 veces
# Estacion_0021215160_paresultado.csv: 1847 veces
# Estacion_0021215170_paresultado.csv: 1847 veces
# Estacion_0021215180_paresultado.csv: 1847 veces
# Estacion_0021215190_paresultado.csv: 1847 veces
# Estacion_0021215501_paresultado.csv: 1847 veces
# Estacion_0021235030_paresultado.csv: 1847 veces
# Estacion_0021237060_paresultado.csv: 1847 veces
# Estacion_0021255090_paresultado.csv: 1847 veces
# Estacion_0021255160_paresultado.csv: 1847 veces
# Estacion_0021255170_paresultado.csv: 1847 veces
# Estacion_0021255501_paresultado.csv: 1847 veces
# Estacion_0022020020_paresultado.csv: 1847 veces
# Estacion_0022025040_paresultado.csv: 1847 veces
# Estacion_0022025501_paresultado.csv: 1847 veces
# Estacion_0022045010_paresultado.csv: 1847 veces
# Estacion_0022045502_paresultado.csv: 1847 veces
# Estacion_0022055020_paresultado.csv: 1847 veces
# Estacion_0022065040_paresultado.csv: 1847 veces
# Estacion_0022070030_paresultado.csv: 1847 veces
# Estacion_0022075050_paresultado.csv: 1847 veces
# Estacion_0023015501_paresultado.csv: 1847 veces
# Estacion_0023020080_paresultado.csv: 1847 veces
# Estacion_0023025040_paresultado.csv: 1847 veces
# Estacion_0023025501_paresultado.csv: 1847 veces
# Estacion_0023025502_paresultado.csv: 1847 veces
# Estacion_0023035030_paresultado.csv: 1847 veces
# Estacion_0023055501_paresultado.csv: 1847 veces
# Estacion_0023055502_paresultado.csv: 1847 veces
# Estacion_0023065110_paresultado.csv: 1847 veces
# Estacion_0023065120_paresultado.csv: 1847 veces
# Estacion_0023065160_paresultado.csv: 1847 veces
# Estacion_0023065180_paresultado.csv: 1847 veces
# Estacion_0023065190_paresultado.csv: 1847 veces
# Estacion_0023065501_paresultado.csv: 1847 veces
# Estacion_0023065502_paresultado.csv: 1847 veces
# Estacion_0023065503_paresultado.csv: 1847 veces
# Estacion_0023065504_paresultado.csv: 1847 veces
# Estacion_0023065505_paresultado.csv: 1847 veces
# Estacion_0023065506_paresultado.csv: 1847 veces
# Estacion_0023067020_paresultado.csv: 1847 veces
# Estacion_0023085080_paresultado.csv: 1847 veces
# Estacion_0023085260_paresultado.csv: 1847 veces
# Estacion_0023085270_paresultado.csv: 1847 veces
# Estacion_0023085501_paresultado.csv: 1847 veces
# Estacion_0023105060_paresultado.csv: 1847 veces
# Estacion_0023105070_paresultado.csv: 1847 veces
# Estacion_0023115010_paresultado.csv: 1847 veces
# Estacion_0023125140_paresultado.csv: 1847 veces
# Estacion_0023125160_paresultado.csv: 1847 veces
# Estacion_0023125170_paresultado.csv: 1847 veces
# Estacion_0023125501_paresultado.csv: 1847 veces
# Estacion_0023155030_paresultado.csv: 1847 veces
# Estacion_0023180070_paresultado.csv: 1847 veces
# Estacion_0023190130_paresultado.csv: 1847 veces
# Estacion_0023190700_paresultado.csv: 1847 veces
# Estacion_0023195040_paresultado.csv: 1847 veces
# Estacion_0023195090_paresultado.csv: 1847 veces
# Estacion_0023195110_paresultado.csv: 1847 veces
# Estacion_0023195190_paresultado.csv: 1847 veces
# Estacion_0023195200_paresultado.csv: 1847 veces
# Estacion_0023195230_paresultado.csv: 1847 veces
# Estacion_0023195240_paresultado.csv: 1847 veces
# Estacion_0023195501_paresultado.csv: 1847 veces
# Estacion_0023195502_paresultado.csv: 1847 veces
# Estacion_0023205050_paresultado.csv: 1847 veces
# Estacion_0024010390_paresultado.csv: 1847 veces
# Estacion_0024015110_paresultado.csv: 1847 veces
# Estacion_0024015300_paresultado.csv: 1847 veces
# Estacion_0024015340_paresultado.csv: 1847 veces
# Estacion_0024015380_paresultado.csv: 1847 veces
# Estacion_0024015501_paresultado.csv: 1847 veces
# Estacion_0024015502_paresultado.csv: 1847 veces
# Estacion_0024015503_paresultado.csv: 1847 veces
# Estacion_0024015504_paresultado.csv: 1847 veces
# Estacion_0024015506_paresultado.csv: 1847 veces
# Estacion_0024015507_paresultado.csv: 1847 veces
# Estacion_0024015508_paresultado.csv: 1847 veces
# Estacion_0024015513_paresultado.csv: 1847 veces
# Estacion_0024025030_paresultado.csv: 1847 veces
# Estacion_0024025050_paresultado.csv: 1847 veces
# Estacion_0024025090_paresultado.csv: 1847 veces
# Estacion_0024025501_paresultado.csv: 1847 veces
# Estacion_0024030350_paresultado.csv: 1847 veces
# Estacion_0024030680_paresultado.csv: 1847 veces
# Estacion_0024030950_paresultado.csv: 1847 veces
# Estacion_0024035250_paresultado.csv: 1847 veces
# Estacion_0024035340_paresultado.csv: 1847 veces
# Estacion_0024035360_paresultado.csv: 1847 veces
# Estacion_0024035370_paresultado.csv: 1847 veces
# Estacion_0024035380_paresultado.csv: 1847 veces
# Estacion_0024035390_paresultado.csv: 1847 veces
# Estacion_0024035410_paresultado.csv: 1847 veces
# Estacion_0024035430_paresultado.csv: 1847 veces
# Estacion_0024035440_paresultado.csv: 1847 veces
# Estacion_0024035501_paresultado.csv: 1847 veces
# Estacion_0024037620_paresultado.csv: 1847 veces
# Estacion_0024055070_paresultado.csv: 1847 veces
# Estacion_0024055080_paresultado.csv: 1847 veces
# Estacion_0024055501_paresultado.csv: 1847 veces
# Estacion_0025010010_paresultado.csv: 1847 veces
# Estacion_0025015020_paresultado.csv: 1847 veces
# Estacion_0025025000_paresultado.csv: 1847 veces
# Estacion_0025025002_paresultado.csv: 1847 veces
# Estacion_0025025030_paresultado.csv: 1847 veces
# Estacion_0025025100_paresultado.csv: 1847 veces
# Estacion_0025025190_paresultado.csv: 1847 veces
# Estacion_0025025240_paresultado.csv: 1847 veces
# Estacion_0025025270_paresultado.csv: 1847 veces
# Estacion_0025025280_paresultado.csv: 1847 veces
# Estacion_0025025330_paresultado.csv: 1847 veces
# Estacion_0025025340_paresultado.csv: 1847 veces
# Estacion_0025025350_paresultado.csv: 1847 veces
# Estacion_0025025360_paresultado.csv: 1847 veces
# Estacion_0025025380_paresultado.csv: 1847 veces
# Estacion_0025027720_paresultado.csv: 1847 veces
# Estacion_0026015010_paresultado.csv: 1847 veces
# Estacion_0026015030_paresultado.csv: 1847 veces
# Estacion_0026015040_paresultado.csv: 1847 veces
# Estacion_0026015050_paresultado.csv: 1847 veces
# Estacion_0026035090_paresultado.csv: 1847 veces
# Estacion_0026035100_paresultado.csv: 1847 veces
# Estacion_0026035501_paresultado.csv: 1847 veces
# Estacion_0026055100_paresultado.csv: 1847 veces
# Estacion_0026055110_paresultado.csv: 1847 veces
# Estacion_0026055120_paresultado.csv: 1847 veces
# Estacion_0026055501_paresultado.csv: 1847 veces
# Estacion_0026065501_paresultado.csv: 1847 veces
# Estacion_0026065502_paresultado.csv: 1847 veces
# Estacion_0026075120_paresultado.csv: 1847 veces
# Estacion_0026075150_paresultado.csv: 1847 veces
# Estacion_0026075501_paresultado.csv: 1847 veces
# Estacion_0026085160_paresultado.csv: 1847 veces
# Estacion_0026085170_paresultado.csv: 1847 veces
# Estacion_0026085501_paresultado.csv: 1847 veces
# Estacion_0026095320_paresultado.csv: 1847 veces
# Estacion_0026105240_paresultado.csv: 1847 veces
# Estacion_0026105250_paresultado.csv: 1847 veces
# Estacion_0026115090_paresultado.csv: 1847 veces
# Estacion_0026115501_paresultado.csv: 1847 veces
# Estacion_0026125061_paresultado.csv: 1847 veces
# Estacion_0026125290_paresultado.csv: 1847 veces
# Estacion_0026125300_paresultado.csv: 1847 veces
# Estacion_0026125501_paresultado.csv: 1847 veces
# Estacion_0026125502_paresultado.csv: 1847 veces
# Estacion_0026125503_paresultado.csv: 1847 veces
# Estacion_0026125504_paresultado.csv: 1847 veces
# Estacion_0026125505_paresultado.csv: 1847 veces
# Estacion_0026125506_paresultado.csv: 1847 veces
# Estacion_0026125507_paresultado.csv: 1847 veces
# Estacion_0026125508_paresultado.csv: 1847 veces
# Estacion_0026125509_paresultado.csv: 1847 veces
# Estacion_0026125710_paresultado.csv: 1847 veces
# Estacion_0026125720_paresultado.csv: 1847 veces
# Estacion_0026125740_paresultado.csv: 1847 veces
# Estacion_0026125760_paresultado.csv: 1847 veces
# Estacion_0026135290_paresultado.csv: 1847 veces
# Estacion_0026135300_paresultado.csv: 1847 veces
# Estacion_0026135310_paresultado.csv: 1847 veces
# Estacion_0026135320_paresultado.csv: 1847 veces
# Estacion_0026135330_paresultado.csv: 1847 veces
# Estacion_0026135501_paresultado.csv: 1847 veces
# Estacion_0026135502_paresultado.csv: 1847 veces
# Estacion_0026135503_paresultado.csv: 1847 veces
# Estacion_0026145090_paresultado.csv: 1847 veces
# Estacion_0026145501_paresultado.csv: 1847 veces
# Estacion_0026145503_paresultado.csv: 1847 veces
# Estacion_0026145504_paresultado.csv: 1847 veces
# Estacion_0026145505_paresultado.csv: 1847 veces
# Estacion_0026145506_paresultado.csv: 1847 veces
# Estacion_0026145507_paresultado.csv: 1847 veces
# Estacion_0026145508_paresultado.csv: 1847 veces
# Estacion_0026155110_paresultado.csv: 1847 veces
# Estacion_0026155150_paresultado.csv: 1847 veces
# Estacion_0026155170_paresultado.csv: 1847 veces
# Estacion_0026155220_paresultado.csv: 1847 veces
# Estacion_0026155230_paresultado.csv: 1847 veces
# Estacion_0026155240_paresultado.csv: 1847 veces
# Estacion_0026155250_paresultado.csv: 1847 veces
# Estacion_0026155260_paresultado.csv: 1847 veces
# Estacion_0026155270_paresultado.csv: 1847 veces
# Estacion_0026155502_paresultado.csv: 1847 veces
# Estacion_0026155503_paresultado.csv: 1847 veces
# Estacion_0026155505_paresultado.csv: 1847 veces
# Estacion_0026157170_paresultado.csv: 1847 veces
# Estacion_0026157190_paresultado.csv: 1847 veces
# Estacion_0026165501_paresultado.csv: 1847 veces
# Estacion_0026165502_paresultado.csv: 1847 veces
# Estacion_0026175501_paresultado.csv: 1847 veces
# Estacion_0026175502_paresultado.csv: 1847 veces
# Estacion_0026180180_paresultado.csv: 1847 veces
# Estacion_0026180250_paresultado.csv: 1847 veces
# Estacion_0026185020_paresultado.csv: 1847 veces
# Estacion_0026185030_paresultado.csv: 1847 veces
# Estacion_0026185050_paresultado.csv: 1847 veces
# Estacion_0026185501_paresultado.csv: 1847 veces
# Estacion_0026195501_paresultado.csv: 1847 veces
# Estacion_0026195502_paresultado.csv: 1847 veces
# Estacion_0026205501_paresultado.csv: 1847 veces
# Estacion_0026215501_paresultado.csv: 1847 veces
# Estacion_0026225060_paresultado.csv: 1847 veces
# Estacion_0026255030_paresultado.csv: 1847 veces
# Estacion_0027015280_paresultado.csv: 1847 veces
# Estacion_0027015290_paresultado.csv: 1847 veces
# Estacion_0027015300_paresultado.csv: 1847 veces
# Estacion_0027015310_paresultado.csv: 1847 veces
# Estacion_0027015320_paresultado.csv: 1847 veces
# Estacion_0027015330_paresultado.csv: 1847 veces
# Estacion_0027015501_paresultado.csv: 1847 veces
# Estacion_0028015070_paresultado.csv: 1847 veces
# Estacion_0028015110_paresultado.csv: 1847 veces
# Estacion_0028025090_paresultado.csv: 1847 veces
# Estacion_0028025120_paresultado.csv: 1847 veces
# Estacion_0028025130_paresultado.csv: 1847 veces
# Estacion_0028025501_paresultado.csv: 1847 veces
# Estacion_0028025502_paresultado.csv: 1847 veces
# Estacion_0028035060_paresultado.csv: 1847 veces
# Estacion_0028035070_paresultado.csv: 1847 veces
# Estacion_0028045501_paresultado.csv: 1847 veces
# Estacion_0029004520_paresultado.csv: 1847 veces
# Estacion_0029015000_paresultado.csv: 1847 veces
# Estacion_0029015040_paresultado.csv: 1847 veces
# Estacion_0029035000_paresultado.csv: 1847 veces
# Estacion_0029035080_paresultado.csv: 1847 veces
# Estacion_0029035200_paresultado.csv: 1847 veces
# Estacion_0029045000_paresultado.csv: 1847 veces
# Estacion_0029045110_paresultado.csv: 1847 veces
# Estacion_0029045150_paresultado.csv: 1847 veces
# Estacion_0029045180_paresultado.csv: 1847 veces
# Estacion_0029045190_paresultado.csv: 1847 veces
# Estacion_0029065000_paresultado.csv: 1847 veces
# Estacion_0029065120_paresultado.csv: 1847 veces
# Estacion_0029065130_paresultado.csv: 1847 veces
# Estacion_0029065140_paresultado.csv: 1847 veces
# Estacion_0029065501_paresultado.csv: 1847 veces
# Estacion_0031095030_paresultado.csv: 1847 veces
# Estacion_0032067030_paresultado.csv: 1847 veces
# Estacion_0032075501_paresultado.csv: 1847 veces
# Estacion_0032105080_paresultado.csv: 1847 veces
# Estacion_0033035010_paresultado.csv: 1847 veces
# Estacion_0035020300_paresultado.csv: 1847 veces
# Estacion_0035025080_paresultado.csv: 1847 veces
# Estacion_0035025090_paresultado.csv: 1847 veces
# Estacion_0035025110_paresultado.csv: 1847 veces
# Estacion_0035025501_paresultado.csv: 1847 veces
# Estacion_0035025502_paresultado.csv: 1847 veces
# Estacion_0035027510_paresultado.csv: 1847 veces
# Estacion_0035035100_paresultado.csv: 1847 veces
# Estacion_0035035110_paresultado.csv: 1847 veces
# Estacion_0035035130_paresultado.csv: 1847 veces
# Estacion_0035060210_paresultado.csv: 1847 veces
# Estacion_0035075040_paresultado.csv: 1847 veces
# Estacion_0035075070_paresultado.csv: 1847 veces
# Estacion_0035075080_paresultado.csv: 1847 veces
# Estacion_0035075090_paresultado.csv: 1847 veces
# Estacion_0035080050_paresultado.csv: 1847 veces
# Estacion_0035085060_paresultado.csv: 1847 veces
# Estacion_0035085070_paresultado.csv: 1847 veces
# Estacion_0035085080_paresultado.csv: 1847 veces
# Estacion_0035095110_paresultado.csv: 1847 veces
# Estacion_0035095120_paresultado.csv: 1847 veces
# Estacion_0035095130_paresultado.csv: 1847 veces
# Estacion_0035105050_paresultado.csv: 1847 veces
# Estacion_0035165000_paresultado.csv: 1847 veces
# Estacion_0035185010_paresultado.csv: 1847 veces
# Estacion_0035195020_paresultado.csv: 1847 veces
# Estacion_0035195050_paresultado.csv: 1847 veces
# Estacion_0035195060_paresultado.csv: 1847 veces
# Estacion_0035215020_paresultado.csv: 1847 veces
# Estacion_0035215030_paresultado.csv: 1847 veces
# Estacion_0035225030_paresultado.csv: 1847 veces
# Estacion_0035235010_paresultado.csv: 1847 veces
# Estacion_0035235040_paresultado.csv: 1847 veces
# Estacion_0035235050_paresultado.csv: 1847 veces
# Estacion_0035237040_paresultado.csv: 1847 veces
# Estacion_0035260050_paresultado.csv: 1847 veces
# Estacion_0036015020_paresultado.csv: 1847 veces
# Estacion_0036015501_paresultado.csv: 1847 veces
# Estacion_0037015030_paresultado.csv: 1847 veces
# Estacion_0037015501_paresultado.csv: 1847 veces
# Estacion_0037045010_paresultado.csv: 1847 veces
# Estacion_0044015060_paresultado.csv: 1847 veces
# Estacion_0044015070_paresultado.csv: 1847 veces
# Estacion_0044015501_paresultado.csv: 1847 veces
# Estacion_0044035040_paresultado.csv: 1847 veces
# Estacion_0044035050_paresultado.csv: 1847 veces
# Estacion_0044035501_paresultado.csv: 1847 veces
# Estacion_0044045030_paresultado.csv: 1847 veces
# Estacion_0044055010_paresultado.csv: 1847 veces
# Estacion_0046015030_paresultado.csv: 1847 veces
# Estacion_0046035010_paresultado.csv: 1847 veces
# Estacion_0047015100_paresultado.csv: 1847 veces
# Estacion_0047035030_paresultado.csv: 1847 veces
# Estacion_0048015010_paresultado.csv: 1847 veces
# Estacion_0048015040_paresultado.csv: 1847 veces
# Estacion_0048015050_paresultado.csv: 1847 veces
# Estacion_0051025060_paresultado.csv: 1847 veces
# Estacion_0051025080_paresultado.csv: 1847 veces
# Estacion_0051025090_paresultado.csv: 1847 veces
# Estacion_0051035020_paresultado.csv: 1847 veces
# Estacion_0052015050_paresultado.csv: 1847 veces
# Estacion_0052015501_paresultado.csv: 1847 veces
# Estacion_0052020070_paresultado.csv: 1847 veces
# Estacion_0052025080_paresultado.csv: 1847 veces
# Estacion_0052025090_paresultado.csv: 1847 veces
# Estacion_0052025501_paresultado.csv: 1847 veces
# Estacion_0052035040_paresultado.csv: 1847 veces
# Estacion_0052035501_paresultado.csv: 1847 veces
# Estacion_0052040050_paresultado.csv: 1847 veces
# Estacion_0052045080_paresultado.csv: 1847 veces
# Estacion_0052050060_paresultado.csv: 1847 veces
# Estacion_0052050080_paresultado.csv: 1847 veces
# Estacion_0052050090_paresultado.csv: 1847 veces
# Estacion_0052055090_paresultado.csv: 1847 veces
# Estacion_0052055150_paresultado.csv: 1847 veces
# Estacion_0052055160_paresultado.csv: 1847 veces
# Estacion_0052055170_paresultado.csv: 1847 veces
# Estacion_0052055210_paresultado.csv: 1847 veces
# Estacion_0052055220_paresultado.csv: 1847 veces
# Estacion_0052055230_paresultado.csv: 1847 veces
# Estacion_0052055501_paresultado.csv: 1847 veces
# Estacion_0052055502_paresultado.csv: 1847 veces
# Estacion_0053045040_paresultado.csv: 1847 veces
# Estacion_0053075020_paresultado.csv: 1847 veces
# Estacion_0053115501_paresultado.csv: 1847 veces
# Estacion_0053115502_paresultado.csv: 1847 veces
# Estacion_0054010010_paresultado.csv: 1847 veces
# Estacion_0054015010_paresultado.csv: 1847 veces
# Estacion_0054015020_paresultado.csv: 1847 veces
# Estacion_0054020020_paresultado.csv: 1847 veces
# Estacion_0054020090_paresultado.csv: 1847 veces
# Estacion_0054025010_paresultado.csv: 1847 veces
# Estacion_0054035501_paresultado.csv: 1847 veces
# Estacion_0054050010_paresultado.csv: 1847 veces
# Estacion_0054077210_paresultado.csv: 1847 veces
# Estacion_0055015010_paresultado.csv: 1847 veces
# Estacion_0055015020_paresultado.csv: 1847 veces
# Estacion_0056010040_paresultado.csv: 1847 veces
# Estacion_0056015010_paresultado.csv: 1847 veces
# Estacion_0056015040_paresultado.csv: 1847 veces
# Estacion_0056019010_paresultado.csv: 1847 veces
# Estacion_0056125730_paresultado.csv: 1847 veces
# Estacion_0057015010_paresultado.csv: 1847 veces
# Estacion_0057025020_paresultado.csv: 1847 veces
# Estacion_1111500036_paresultado.csv: 1847 veces
# Estacion_1117500060_paresultado.csv: 1847 veces
# Estacion_1206500136_paresultado.csv: 1847 veces
# Estacion_1303500074_paresultado.csv: 1847 veces
# Estacion_1303500129_paresultado.csv: 1847 veces
# Estacion_1501500054_paresultado.csv: 1847 veces
# Estacion_1507500207_paresultado.csv: 1847 veces
# Estacion_1508500053_paresultado.csv: 1847 veces
# Estacion_1509500118_paresultado.csv: 1847 veces
# Estacion_1602500044_paresultado.csv: 1847 veces
# Estacion_1602500063_paresultado.csv: 1847 veces
# Estacion_1602500110_paresultado.csv: 1847 veces
# Estacion_2119500111_paresultado.csv: 1847 veces
# Estacion_2120000099_paresultado.csv: 1847 veces
# Estacion_2120000100_paresultado.csv: 1847 veces
# Estacion_2120000102_paresultado.csv: 1847 veces
# Estacion_2120000104_paresultado.csv: 1847 veces
# Estacion_2120000105_paresultado.csv: 1847 veces
# Estacion_2120000106_paresultado.csv: 1847 veces
# Estacion_2120000107_paresultado.csv: 1847 veces
# Estacion_2120500050_paresultado.csv: 1847 veces
# Estacion_2120500135_paresultado.csv: 1847 veces
# Estacion_2120700037_paresultado.csv: 1847 veces
# Estacion_2120700038_paresultado.csv: 1847 veces
# Estacion_2121500042_paresultado.csv: 1847 veces
# Estacion_2121500048_paresultado.csv: 1847 veces
# Estacion_2201500047_paresultado.csv: 1847 veces
# Estacion_2202500051_paresultado.csv: 1847 veces
# Estacion_2302500037_paresultado.csv: 1847 veces
# Estacion_2302500064_paresultado.csv: 1847 veces
# Estacion_2305500055_paresultado.csv: 1847 veces
# Estacion_2306500106_paresultado.csv: 1847 veces
# Estacion_2308500068_paresultado.csv: 1847 veces
# Estacion_2308500071_paresultado.csv: 1847 veces
# Estacion_2319500043_paresultado.csv: 1847 veces
# Estacion_2319500125_paresultado.csv: 1847 veces
# Estacion_2319500137_paresultado.csv: 1847 veces
# Estacion_2401500040_paresultado.csv: 1847 veces
# Estacion_2401500052_paresultado.csv: 1847 veces
# Estacion_2401500080_paresultado.csv: 1847 veces
# Estacion_2401500086_paresultado.csv: 1847 veces
# Estacion_2403000117_paresultado.csv: 1847 veces
# Estacion_2403500041_paresultado.csv: 1847 veces
# Estacion_2403500081_paresultado.csv: 1847 veces
# Estacion_2403500082_paresultado.csv: 1847 veces
# Estacion_2403500083_paresultado.csv: 1847 veces
# Estacion_2403500084_paresultado.csv: 1847 veces
# Estacion_2403500085_paresultado.csv: 1847 veces
# Estacion_2501500120_paresultado.csv: 1847 veces
# Estacion_2603500127_paresultado.csv: 1847 veces
# Estacion_2604500039_paresultado.csv: 1847 veces
# Estacion_2604500134_paresultado.csv: 1847 veces
# Estacion_2610500131_paresultado.csv: 1847 veces
# Estacion_2612500038_paresultado.csv: 1847 veces
# Estacion_2612500124_paresultado.csv: 1847 veces
# Estacion_2612500130_paresultado.csv: 1847 veces
# Estacion_2613500126_paresultado.csv: 1847 veces
# Estacion_2614500112_paresultado.csv: 1847 veces
# Estacion_2614500116_paresultado.csv: 1847 veces
# Estacion_2615500122_paresultado.csv: 1847 veces
# Estacion_2621500070_paresultado.csv: 1847 veces
# Estacion_2701500105_paresultado.csv: 1847 veces
# Estacion_2702500107_paresultado.csv: 1847 veces
# Estacion_2801500078_paresultado.csv: 1847 veces
# Estacion_2802500079_paresultado.csv: 1847 veces
# Estacion_2804500076_paresultado.csv: 1847 veces
# Estacion_2805500075_paresultado.csv: 1847 veces
# Estacion_2901500072_paresultado.csv: 1847 veces
# Estacion_2906500077_paresultado.csv: 1847 veces
# Estacion_3206500045_paresultado.csv: 1847 veces
# Estacion_3206500058_paresultado.csv: 1847 veces
# Estacion_3206500059_paresultado.csv: 1847 veces
# Estacion_3502500135_paresultado.csv: 1847 veces
# Estacion_3503500062_paresultado.csv: 1847 veces
# Estacion_3505500061_paresultado.csv: 1847 veces
# Estacion_3507500046_paresultado.csv: 1847 veces
# Estacion_3507500133_paresultado.csv: 1847 veces
# Estacion_3518500127_paresultado.csv: 1847 veces
# Estacion_3526500201_paresultado.csv: 1847 veces
# Estacion_3701500114_paresultado.csv: 1847 veces
# Estacion_3701500117_paresultado.csv: 1847 veces
# Estacion_3702500113_paresultado.csv: 1847 veces
# Estacion_3706500109_paresultado.csv: 1847 veces
# Estacion_5102500128_paresultado.csv: 1847 veces
# Estacion_5202500132_paresultado.csv: 1847 veces
# Estacion_5205500123_paresultado.csv: 1847 veces
# Estacion_5311500056_paresultado.csv: 1847 veces
# Estacion_5311500121_paresultado.csv: 1847 veces
# Estacion_5311500149_paresultado.csv: 1847 veces

# %% [markdown]
# _____

# %% [markdown]
# ## Cantidad de datos abanderados al aplicar QC automatizados

# %%
## Cantidad y porcentaje de datos abanderados por estación
def generar_dataframe_compilado(archivos):
    datos = []

    for archivo in archivos:
        # Leer el archivo CSV en modo iterador y especificar los tipos de datos
        reader = pd.read_csv(archivo, iterator=True, dtype={'Station': str, 'Estado': str}, chunksize=70000, 
                             encoding='latin-1')

        # Inicializar contador de filas y contador de '0PAT0'
        total_filas = 0
        cantidad_0PSO = 0
        cantidad_0PER = 0
        cantidad_0PAT = 0
        #cantidad_0PC = 0

        # Obtener los chunks de datos del archivo
        for chunk in reader:
            total_filas += len(chunk)
            cantidad_0PSO +=  chunk[chunk['Estado'].str.startswith('0PSO', na=False)].shape[0]
            cantidad_0PER +=  chunk[chunk['Estado'].str.startswith('0PER', na=False)].shape[0]
            cantidad_0PAT +=  chunk[chunk['Estado'].str.startswith('0PAT', na=False)].shape[0]
            #cantidad_0PC += chunk[chunk['Estado'].str.startswith('0PC', na=False)].shape[0]

        cantidad_0P = cantidad_0PSO + cantidad_0PER + cantidad_0PAT
        
        # Obtener el 'Station' respectivo
        station = chunk['Station'].iloc[0]
        
        # Obtener porcentajes
        perc_0PSO = round((cantidad_0PSO/total_filas*100),2)
        perc_0PER = round((cantidad_0PER/total_filas*100),2)
        perc_0PAT = round((cantidad_0PAT/total_filas*100),2)
        perc_0P = round((cantidad_0P/total_filas*100),2)
        #perc_0PC = round((cantidad_0PC/total_filas*100),2)

        # Agregar los datos a la lista
        datos.append({'Station': station, 'TotalDatos': total_filas, 'Estado_0PSO': cantidad_0PSO, 
                      'Estado_0PAT': cantidad_0PAT, 'Estado_0PER': cantidad_0PER, 'Estado_0P': cantidad_0P,
                      'Per_0PSO': perc_0PSO, 'Per_0PAT': perc_0PAT, #'Estado_0PC': cantidad_0PC,
                      'Per_0PER': perc_0PER, 'Per_0P': perc_0P}) #, 'Per_0PC': perc_0PC})
        #print(datos)

    # Crear el nuevo DataFrame compilado
    df_compilado = pd.DataFrame(datos)

    return df_compilado

# Ruta de la carpeta con los archivos CSV
carpeta = '../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3/'

# Obtener la lista de archivos en la carpeta
archivos = [carpeta + archivo for archivo in os.listdir(carpeta) if archivo.endswith('.csv')]

# Llamar a la función para generar el nuevo DataFrame compilado
df_compilado = generar_dataframe_compilado(archivos)

# Imprimir el nuevo DataFrame
print(df_compilado)

# Exportar el df compilado
df_compilado.to_csv('Patm_0P.csv', index=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\3587612402.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
#         Station  TotalDatos  Estado_0PSO  Estado_0PAT  Estado_0PER  Estado_0P  \
# 0      11030010       42068          214         1636          159       2009
# 1      11035030       19392           29          123           35        187
# 2      11045010       44126           94          288            0        382
# 3      11050020       20954           33          120           45        198
# 4      11080010       34517          140          183         1196       1519
# ..          ...         ...          ...          ...          ...        ...
# 419  5205500123       31304          404          258            0        662
# 420  5311500056       33876          125          345            3        473
# 421  5311500121       51566           11          247            0        258
# 422  5311500147      155686       134670          234         9671     144575
# 423  5311500149      136197       119249          248         8806     128303
#
#      Per_0PSO  Per_0PAT  Per_0PER  Per_0P
# 0        0.51      3.89      0.38    4.78
# 1        0.15      0.63      0.18    0.96
# 2        0.21      0.65      0.00    0.87
# 3        0.16      0.57      0.21    0.94
# 4        0.41      0.53      3.46    4.40
# ..        ...       ...       ...     ...
# 419      1.29      0.82      0.00    2.11
# 420      0.37      1.02      0.01    1.40
# 421      0.02      0.48      0.00    0.50
# 422     86.50      0.15      6.21   92.86
# 423     87.56      0.18      6.47   94.20
#
# [424 rows x 10 columns]

# %%
## Cantidad y porcentaje de datos abanderados por entidad
def generar_dataframe_compilado(archivos):
    datos = []

    for archivo in archivos:
        # Leer el archivo CSV en modo iterador y especificar los tipos de datos
        reader = pd.read_csv(archivo, iterator=True, dtype={'Station': str, 'Estado': str}, chunksize=70000,
                            encoding='latin-1')

        # Inicializar contador de filas y contador de '0PAT0'
        total_filas = 0
        cantidad_0PSO = 0
        cantidad_0PER = 0
        cantidad_0PAT = 0
        cantidad_0PC = 0

        # Obtener los chunks de datos del archivo
        for chunk in reader:
            total_filas += len(chunk)
            cantidad_0PSO +=  chunk[chunk['Estado'].str.startswith('0PSO', na=False)].shape[0]
            cantidad_0PER +=  chunk[chunk['Estado'].str.startswith('0PER', na=False)].shape[0]
            cantidad_0PAT +=  chunk[chunk['Estado'].str.startswith('0PAT', na=False)].shape[0]
            cantidad_0PC += chunk[chunk['Estado'].str.startswith('0PC', na=False)].shape[0]

        cantidad_0P = cantidad_0PSO + cantidad_0PER + cantidad_0PAT
        
        # Obtener el 'Station' respectivo
        station = chunk['Station'].iloc[0]
        
        # Obtener porcentajes
        perc_0PSO = round((cantidad_0PSO/total_filas*100),2)
        perc_0PER = round((cantidad_0PER/total_filas*100),2)
        perc_0PAT = round((cantidad_0PAT/total_filas*100),2)
        perc_0P = round((cantidad_0P/total_filas*100),2)
        perc_0PC = round((cantidad_0PC/total_filas*100),2)

        # Agregar los datos a la lista
        datos.append({'Station': station, 'TotalDatos': total_filas, 'Estado_0PSO': cantidad_0PSO, 
                      'Estado_0PAT': cantidad_0PAT, 'Estado_0PER': cantidad_0PER, 'Estado_0P': cantidad_0P,
                      'Estado_0PC': cantidad_0PC, 'Per_0PSO': perc_0PSO, 'Per_0PAT': perc_0PAT, 
                      'Per_0PER': perc_0PER, 'Per_0P': perc_0P, 'Per_0PC': perc_0PC})

    # Crear el nuevo DataFrame compilado
    df_compilado = pd.DataFrame(datos)
    # Convertir la columna 'Station' a tipo 'int64'
    df_compilado['Station'] = df_compilado['Station'].astype('int64')

    # Cargar el archivo 'EMA_AllInfo.txt'
    ema_all = pd.read_csv('EMAPatm_allinfo.txt', delimiter=';', encoding='latin-1')
    
    # Convertir la columna 'Station' a tipo 'str'
    ema_all['Station'] = ema_all['Station'].astype('int64')
    
    # Unir los dataframes para agregar la columna 'project'
    df_compilado = pd.merge(df_compilado, ema_all[['Station', 'project']], on='Station', how='left')

    # Agrupar por proyecto y obtener los resultados deseados
    resultado = df_compilado.groupby('project').agg({
        'TotalDatos': 'sum',
        'Estado_0PSO': 'sum',
        'Estado_0PAT': 'sum',
        'Estado_0PER': 'sum',
        'Estado_0P': 'sum',
        'Estado_0PC': 'sum',
        'Per_0PSO': 'mean',
        'Per_0PAT': 'mean',
        'Per_0PER': 'mean',
        'Per_0P': 'mean',
        'Per_0PC': 'mean',
    }).reset_index()

    return resultado

# Ruta de la carpeta con los archivos CSV
carpeta = '../OE_3_QC_Variables/1_PresionAtmosferica/QCResult_Patm/V3/'

# Obtener la lista de archivos en la carpeta
archivos = [carpeta + archivo for archivo in os.listdir(carpeta) if archivo.endswith('.csv')]

# Llamar a la función para generar el nuevo DataFrame compilado
df_compilado = generar_dataframe_compilado(archivos)

# Imprimir el nuevo DataFrame
print(df_compilado)

# Exportar el df compilado
df_compilado.to_csv('Patm_0P_entidad.csv', index=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# C:\Users\user\AppData\Local\Temp\ipykernel_11480\2534340331.py:18: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11480\2534340331.py in <cell line: 0>()
#      79
#      80 # Llamar a la función para generar el nuevo DataFrame compilado
# ---> 81 df_compilado = generar_dataframe_compilado(archivos)
#      82
#      83 # Imprimir el nuevo DataFrame
#
# ~\AppData\Local\Temp\ipykernel_11480\2534340331.py in generar_dataframe_compilado(archivos)
#      47
#      48     # Cargar el archivo 'EMA_AllInfo.txt'
# ---> 49     ema_all = pd.read_csv('EMAPatm_allinfo.txt', delimiter=';', encoding='latin-1')
#      50
#      51     # Convertir la columna 'Station' a tipo 'str'
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'EMAPatm_allinfo.txt'
